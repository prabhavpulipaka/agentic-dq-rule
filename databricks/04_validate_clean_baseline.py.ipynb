# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA dq_demo")

tables = ["customers", "orders", "order_items", "payments"]

for table in tables:
    df = spark.table(f"workspace.dq_demo.{table}")
    print(f"{table}: {df.count()} rows")
    display(df.limit(5))
